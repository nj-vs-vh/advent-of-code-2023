# %%
from pathlib import Path
import networkx as nx
from solution import parse_graph

# %%
# path = Path("input.txt")
path = Path("test.txt")
graph_data = parse_graph(path.read_text())
G = nx.Graph(graph_data)
nx.draw(G, with_labels=True)
